# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('/home/cc/data/openimages/train-images-boxable-with-rotation.csv')

# Get the number of rows
num_rows = len(df)

print("Number of rows:", num_rows)
# Out:
# Number of rows: 1743042

# %%
import random

# Generate 10,000 random numbers
random_numbers = random.sample(range(1, 1743043), 10000)

print(random_numbers)
# Out:
# [1395463, 1349999, 1566129, 1436578, 1448842, 939925, 536457, 512321, 904762, 1445695, 1208177, 1470085, 876075, 1195859, 5787, 1504466, 1045501, 1390036, 86681, 987356, 207222, 893439, 1448072, 1090486, 258720, 1296656, 1265961, 1134083, 1507242, 1602901, 1170435, 1242195, 598657, 414289, 1247122, 418489, 943447, 1167903, 1416398, 1591730, 1128435, 1103215, 1204011, 285162, 1734528, 342161, 1590350, 505270, 820214, 1434042, 1009989, 575591, 942234, 106482, 1305872, 1741399, 1437829, 440761, 142286, 1265167, 1329731, 100948, 62902, 3608, 711142, 259780, 1256547, 881787, 545016, 693704, 24251, 1172937, 1361386, 558294, 1380678, 1534754, 1083161, 1403540, 916336, 156926, 1464280, 1077935, 118211, 703820, 1085625, 1319112, 1230665, 1241277, 751264, 680318, 1384742, 949871, 1565426, 266755, 814636, 1140004, 1576146, 34710, 544936, 843027, 756302, 742894, 1337257, 1631909, 1492389, 562113, 705271, 1614407, 995249, 690702, 1729734, 1685252, 966411, 1311486, 259932, 662225, 108912, 1357006,
# ...

# %%
with open("/home/cc/data/openimages/ids.txt", "w") as f:
    for index in random_numbers:
        image_id = df.at[index, 'ImageID']
        f.write(f"train/{image_id}\n")
